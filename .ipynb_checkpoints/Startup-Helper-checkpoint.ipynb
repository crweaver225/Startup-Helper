# %% [markdown]
# ### Introduction
#
# The majority of startups will fail within the first couple years of opening up. Considering the amount of money,  effort, and time involved in starting a business; entrepreneurs needs every advantage they can get. This data science project is designed to help entrepreneur's pick the best area in the city of Chicago to start their new coffee house. We will review different data points for each of Chicago's 77 neighborhoods and see if we can find any corollaries between aspects of these neighborhoods and positive metrics from Foursquare to help predict success.

# %%
# First I need to import my libraries

import numpy as np

import pandas as pd
from pandas.io.json import json_normalize
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import requests

import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

from bs4 import BeautifulSoup

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

from sklearn.model_selection import train_test_split
from sklearn import svm

# %% [markdown]
# ### Data Collection
#
# First step is to collect data. I have three sources of data I will be collecting from.
#
# 1. Wikipedia. All the basic neighborhood data exists on this wikipedia page (https://en.wikipedia.org/wiki/Community_areas_in_Chicago), I will grab the data using a web crawler.
# 2. Cmap. I will be utilizing data provided at this link (https://www.cmap.illinois.gov/data/community-snapshots) to get more detailed demographic information for each neighborhood.
# 3. Foursquare. I will be utilizing a couple Foursquare api's to gather data about different Coffee houses in all 77 neighborhoods.

# %% [markdown]
# #### Wikipedia
# First, I will build a web crawler to get data for all neighborhoods from wikipedia

# %%
# Web scrape a wikipedia page for chicago community data
results = requests.get("https://en.wikipedia.org/wiki/Community_areas_in_Chicago")
soup = BeautifulSoup(results.content)

# %%
# Get neighborhood name, population, size in square miles, and density from wikipedia page
table=soup.find('table')
rows = table.find_all('tr')

table_contents = []

for row in rows[2:-1]:
    
    cell = {}
    
    community_title = row.find('th')
    links = row.find('a', href=True)
    title = links.string
    
    community_data = row.findAll('td')
    population = community_data[1:][0].text
    area = community_data[1:][1].text
    density = community_data[1:][3].text
    
    cell['title'] = title.strip()
    cell['population'] = population
    cell['area_sq_mi'] = area
    cell['density'] = density
    
    table_contents.append(cell)

# %%
# Convert web scraping to a Dataframe
df=pd.DataFrame(table_contents)
df.head()
# Out:
#             title population area_sq_mi    density
# 0     Rogers Park     55,475       1.84  30,149.46
# 1      West Ridge     78,466       3.53  22,228.33
# 2          Uptown     58,979       2.32  25,421.98
# 3  Lincoln Square     42,103       2.56  16,446.48
# 4    North Center     35,543       2.05  17,338.05

# %% [markdown]
# #### Cmap
#
# I found demographic data at https://www.cmap.illinois.gov/data/community-snapshots. I downloaded the dataset and stored as a csv. I will load this up now and integrate it into the dataframe above. The data goes back to 1930. I will only be using data from 2015-2019 as this is most relevant for insights into a new Cafe.

# %%
# Found demographic data for neighborhoods elsewhere, downloaded the csv. I will now load the csv into a Dataframe
df2 = pd.read_csv("demographics.csv")
df2.head()
# Out:
#   Race and Ethnicity in Chicago Community Areas Unnamed: 1 Unnamed: 2  \
# 0                                           NaN       1930       1940
# 1                                1. Rogers Park        NaN        NaN
# 2                                         Total    57,094     60,565
# 3                                         Asian        NaN        NaN
# 4                     Black or African-American       128        130
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0       1950       1960       1970
# 1        NaN        NaN        NaN
# 2    62,252     56,888     60,787
# 3        NaN        NaN     1,620
# 4       108         57        762
#
#                                           Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0                                                NaN       1980       1990
# 1                                     1. Rogers Park        NaN        NaN
# 2                                             Total     55,525     60,378
# ...

# %%
# Some data wrangling on the csv for demographics so that I know what values represent
columns = []
for idx, c in enumerate(df2['Unnamed: 6']):
    column = {}
    if '.' in str(c):
        community = c.split('. ')[1]
        total = df2.iloc[idx + 1]['Unnamed: 18']
        asian = df2.iloc[idx + 2]['Unnamed: 18']
        black = df2.iloc[idx + 3]['Unnamed: 18']
        hispanic = df2.iloc[idx + 4]['Unnamed: 18']
        white = df2.iloc[idx + 5]['Unnamed: 18']
        
        column['title'] = community.strip()
        column['total'] = total
        column['asian'] = asian
        column['black'] = black
        column['hispanic'] = hispanic
        column['white'] = white
        
        columns.append(column)

df3 = pd.DataFrame(columns)
df3.head()
# Out:
#             title   total   asian   black hispanic   white
# 0     Rogers Park  55,475   2,695  15,187   10,887  24,357
# 1      West Ridge  78,466  18,650   9,086   14,835  31,836
# 2          Uptown  58,979   6,207  10,476    8,609  31,974
# 3  Lincoln Square  42,103   3,820   1,470    7,611  27,165
# 4    North Center  35,543   1,737     750    4,070  27,629

# %%
# Going to add web scraping data and demographic data into one dataframe

neighborhood_df = pd.merge(df, df3, on=["title"])
neighborhood_df.head()
# Out:
#             title population area_sq_mi    density   total   asian   black  \
# 0     Rogers Park     55,475       1.84  30,149.46  55,475   2,695  15,187
# 1      West Ridge     78,466       3.53  22,228.33  78,466  18,650   9,086
# 2          Uptown     58,979       2.32  25,421.98  58,979   6,207  10,476
# 3  Lincoln Square     42,103       2.56  16,446.48  42,103   3,820   1,470
# 4    North Center     35,543       2.05  17,338.05  35,543   1,737     750
#
#   hispanic   white
# 0   10,887  24,357
# 1   14,835  31,836
# 2    8,609  31,974
# 3    7,611  27,165
# 4    4,070  27,629

# %% [markdown]
# #### Foursquare
#
# I now will need to get information from Foursquare about different Coffee houses in all 77 of Chicago's neighborhoods. I will have to break this down into two different functions. The first to retrieve all the cafe venues in all those neighborhoods and the second to get more granular metrics about each venue

# %%
# Foursquare api info

CLIENT_ID = 'QNY4BLCNST4M2RWWZ5GG3DE44LGK0N5N5ZXU2AB045UZZRMO' # your Foursquare ID
CLIENT_SECRET = 'ATTMHTXYH0COJUK2GQ1IZZ2V00HU2B4MM33P4OSK5HDIL5JL' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
LIMIT = 1000 # A default Foursquare API limit value

# %%
# A function that will utilize the Foursquare api to get restaurants for each neighborhood

def getNearbyVenues(names, radius=1000):
    
    venues_list=[]
    found_neighborhoods = []
    for name in names:
 
        url_name = '{}, IL'.format(name)

        url = 'https://api.foursquare.com/v2/venues/search?&client_id={}&client_secret={}&query=cafe&v={}&near={}&radius={}&limit={}&sortByDistance=1'.format(
                CLIENT_ID, 
                CLIENT_SECRET, 
                VERSION, 
                url_name,
                radius, 
                LIMIT)
       
            
        # make the GET request
        json_return = requests.get(url).json()
   
        if len(json_return["response"]) > 0:
              
            if 'venues' in json_return["response"]:
                results = json_return["response"]['venues']
    
                # return only relevant information for each nearby venue
                venues_list.append([(
                    name,  
                    v['name'], 
                    v['id'],
                    v['location']['lat'], 
                    v['location']['lng']) for v in results])
    
        nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
        nearby_venues.columns = ['Neighborhood',  
                      'Venue', 
                      'Venue id',
                      'Venue Latitude', 
                      'Venue Longitude']
    return(nearby_venues)

# %%
# I have downloaded this data and saved to csv, no need to go again
#nearby_venues = getNearbyVenues(neighborhood_df['title'].tolist())
#nearby_venues.to_csv('venue_info.csv')

# Since the venue information for each neighborhood was previously downloaded and saved to a csv, 
# I can now simply load it up
nearby_venues = pd.read_csv('venue_info.csv')
nearby_venues.drop(columns={'Unnamed: 0'}, inplace=True)
print("There are {} venues in this dataset".format(nearby_venues.shape[0]))
nearby_venues.head()
# Out:
# There are 529 venues in this dataset
#   Neighborhood                   Venue                  Venue id  \
# 0  Rogers Park           Charmers Cafe  5710dcf0498e87c71d20b69d
# 1  Rogers Park                Sol Café  505d49ede4b0236a27575f1b
# 2  Rogers Park  Athena Board Game Cafe  5fa839e108db5a66e12686f6
# 3  Rogers Park                  Cafe B  4f6691c5e4b062549d1992f4
# 4  Rogers Park                  Cafe A  4f669196e4b08ac726f66479
#
#    Venue Latitude  Venue Longitude
# 0       42.016164       -87.668250
# 1       42.019306       -87.672078
# 2       42.019366       -87.667185
# 3       42.019043       -87.674900
# 4       42.019005       -87.675057

# %%
# Load the granular metric data for a specific venue by id using the Foursquare api

def getVisitorDataForVenue(ids):
    
    venue_details_df = pd.DataFrame(columns=['id','tipCount', 'likes', 'rating'])
    
    for id in ids:
       
        url = 'https://api.foursquare.com/v2/venues/{}?&client_id={}&client_secret={}&v={}'.format(
                    id,
                    CLIENT_ID, 
                    CLIENT_SECRET, 
                    VERSION)
        json_return = requests.get(url).json()["response"]
    
        if 'venue' in json_return:
            
            data = {}
        
            venue = json_return['venue']
            
            data['id'] = id
            
            if 'stats' in venue:
                stats = venue['stats']
                if 'tipCount' in stats:
                    data['tipCount'] = stats['tipCount']
            
            if 'likes' in venue:
                likes = venue['likes']
                if 'count' in likes:
                    data['likes'] = likes['count']
            
            if 'rating' in venue:
                data['rating'] = venue['rating']
        
            venue_details_df = venue_details_df.append(data, ignore_index=True)
        
    return venue_details_df

# %%
# This details call is a premium call and can only be made 500 times per day
# Since i have over 500 records, i will only call the first 150, save them and finish tomorrow
#venue_details_first150_df = getVisitorDataForVenue(nearby_venues['Venue id'][:150])
#venue_details_first150_df.dropna(inplace=True, axis=0)
#venue_details_first150_df.to_csv('venue_details.csv')
#venue_details_first150_df.head(10)

# Next time run this
venue_details_first150_df = pd.read_csv('venue_details.csv')
venue_details_first150_df.drop(columns={'Unnamed: 0'}, inplace=True)
venue_details_first150_df.head()
# Out:
#                          id  tipCount  likes  rating
# 0  5710dcf0498e87c71d20b69d         3     14     8.0
# 1  505d49ede4b0236a27575f1b        33     91     8.9
# 2  536eae04498ed93756543fb5         2     11     6.2
# 3  4b5a68abf964a52040c328e3         9     33     7.6
# 4  43655e80f964a5206d291fe3        58    116     8.9

# %%
# Only call this the first time. We will save the data and load after that
#venue_details_last_df = getVisitorDataForVenue(nearby_venues['Venue id'][150:])
#venue_details_last_df.dropna(inplace=True, axis=0)
#venue_details_last_df.to_csv('venue_details2.csv')

venue_details_last_df = pd.read_csv('venue_details2.csv')
venue_details_last_df.drop(columns={'Unnamed: 0'}, inplace=True)
venue_details_last_df.head()
# Out:
#                          id  tipCount  likes  rating
# 0  4bd0edd1a8b3a593cbfd645f        26     31     8.0
# 1  5c124f8e5a2c91002cd2dc5c         2     11     8.0
# 2  4afef141f964a520ec3122e3        28     35     7.1
# 3  54790b93498e7162d99f4f94        14     38     8.6
# 4  55ecdd5a498ece8f3c76d39a         3      4     6.6

# %%
# Only call the first time, we will save after this and load thereafter
#venue_details_df = pd.concat([venue_details_first150_df, venue_details_last_df], ignore_index=True, sort=False)
#venue_details_df.to_csv('venue_details_combined.csv')

venue_details_df = pd.read_csv('venue_details_combined.csv')
venue_details_df.rename(columns={'id': 'Venue id'}, inplace=True)
print(venue_details_df.shape)
venue_details_df.head()
# Out:
# (171, 5)
#    Unnamed: 0                  Venue id  tipCount  likes  rating
# 0           0  5710dcf0498e87c71d20b69d         3     14     8.0
# 1           1  505d49ede4b0236a27575f1b        33     91     8.9
# 2           2  536eae04498ed93756543fb5         2     11     6.2
# 3           3  4b5a68abf964a52040c328e3         9     33     7.6
# 4           4  43655e80f964a5206d291fe3        58    116     8.9

# %%
# Finally, lets merge all the venue data into one dataframe

# Run this once, we will save and load in future if needed
#final_venue_df = pd.merge(nearby_venues, venue_details_df, on=["Venue id"])
#final_venue_df.to_csv('final_venue_df.csv')

final_venue_df = pd.read_csv('final_venue_df.csv')
final_venue_df.drop(columns={'Unnamed: 0'}, inplace=True)
final_venue_df.rename(columns={'Neighborhood': 'title'}, inplace=True)
final_venue_df = pd.merge(final_venue_df, neighborhood_df, on=["title"])

final_venue_df.head()
# Out:
#          title           Venue                  Venue id  Venue Latitude  \
# 0  Rogers Park   Charmers Cafe  5710dcf0498e87c71d20b69d       42.016164
# 1  Rogers Park        Sol Café  505d49ede4b0236a27575f1b       42.019306
# 2   West Ridge    Patel's Cafe  536eae04498ed93756543fb5       41.997723
# 3   West Ridge  Patel Brothers  4b5a68abf964a52040c328e3       41.997769
# 4       Uptown       Kopi Café  43655e80f964a5206d291fe3       41.978612
#
#    Venue Longitude  tipCount  likes  rating population area_sq_mi    density  \
# 0       -87.668250         3     14     8.0     55,475       1.84  30,149.46
# 1       -87.672078        33     91     8.9     55,475       1.84  30,149.46
# 2       -87.694857         2     11     6.2     78,466       3.53  22,228.33
# 3       -87.695282         9     33     7.6     78,466       3.53  22,228.33
# 4       -87.668298        58    116     8.9     58,979       2.32  25,421.98
#
#     total   asian   black hispanic   white
# ...

# %%
# I need final_venue to display all numeric data in float type
columns_to_change = ['population', 'area_sq_mi', 'density', 'total', 'asian', 'black', 'hispanic', 'white']

final_venue_df[columns_to_change] = final_venue_df[columns_to_change].replace(',','', regex=True)
final_venue_df[columns_to_change] = final_venue_df[columns_to_change].replace('-','0', regex=True)
final_venue_df[columns_to_change] = final_venue_df[columns_to_change].astype(float)
final_venue_df.head()
# Out:
#          title           Venue                  Venue id  Venue Latitude  \
# 0  Rogers Park   Charmers Cafe  5710dcf0498e87c71d20b69d       42.016164
# 1  Rogers Park        Sol Café  505d49ede4b0236a27575f1b       42.019306
# 2   West Ridge    Patel's Cafe  536eae04498ed93756543fb5       41.997723
# 3   West Ridge  Patel Brothers  4b5a68abf964a52040c328e3       41.997769
# 4       Uptown       Kopi Café  43655e80f964a5206d291fe3       41.978612
#
#    Venue Longitude  tipCount  likes  rating  population  area_sq_mi   density  \
# 0       -87.668250         3     14     8.0     55475.0        1.84  30149.46
# 1       -87.672078        33     91     8.9     55475.0        1.84  30149.46
# 2       -87.694857         2     11     6.2     78466.0        3.53  22228.33
# 3       -87.695282         9     33     7.6     78466.0        3.53  22228.33
# 4       -87.668298        58    116     8.9     58979.0        2.32  25421.98
#
#      total    asian    black  hispanic    white
# ...

# %% [markdown]
# ### Data Exploration
#
# Second step is to explore the data. Initial analysis of the available data will help provide insights into relationships between different datapoints. These insights are not only valuable within themselves, but will help inform on the types of models we may be able to produce to help us with our business problem.

# %% [markdown]
# Some interesting data here that correlates. Nothing stands out as a major correlation, but lots of marginally significant correlations that could help a model make predictions. Those that stand out to me the most are:
#
# 1. correlation between hispanic population and good rating for a cafe. This is also seen in total population
# 2. larger square miles of a neighborhood seems to correlate with higher ratings
# 3. ratings, likes, and tips all seem to be correlated
#
# Ploting this data as I did below though shows this correlation is very weak. The data is not linear

# %%
final_venue_df.corr()
# Out:
#                  Venue Latitude  Venue Longitude  tipCount     likes  \
# Venue Latitude         1.000000         0.764295  0.049765  0.060657
# Venue Longitude        0.764295         1.000000  0.035329  0.035949
# tipCount               0.049765         0.035329  1.000000  0.970437
# likes                  0.060657         0.035949  0.970437  1.000000
# rating                 0.039480        -0.060689  0.345447  0.385015
# population             0.233477        -0.025243  0.030871  0.022340
# area_sq_mi             0.010007        -0.171375 -0.038560 -0.028859
# density                0.307222         0.123456  0.070823  0.052763
# total                  0.234668        -0.025738  0.034519  0.026097
# asian                  0.209865         0.136554 -0.000405 -0.008814
# black                 -0.140806        -0.146410 -0.149181 -0.145628
# hispanic               0.129680        -0.090192  0.103151  0.101831
# white                  0.218718         0.044158  0.030926  0.021901
#
# ...

# %%
# total population as potential predictor variable of rating
sns.regplot(x="total", y="rating", data=final_venue_df)
plt.ylim(0,)
# Out:
# (0.0, 9.510000000000002)

# %%
# Hispanic size as potential predictor variable of rating
sns.regplot(x="hispanic", y="rating", data=final_venue_df)
plt.ylim(0,)
# Out:
# (0.0, 9.913386659844235)

# %%
# Neighborhood geographical size as potential predictor variable of rating
sns.regplot(x="area_sq_mi", y="rating", data=final_venue_df)
plt.ylim(0,)
# Out:
# (0.0, 10.828194770895536)

# %% [markdown]
# Lets see if certain neighborhoods are more likely to rate cafe's higher than others

# %%
neighborhood_rating_df = final_venue_df[['title','rating']]
neighborhood_rating_df = neighborhood_rating_df.groupby(['title'], as_index=False).mean()
neighborhood_rating_df.sort_values(by=['rating'], inplace=True, ascending=False,ignore_index=True)
neighborhood_rating_df
# Out:
#               title    rating
# 0    South Lawndale  8.900000
# 1      Logan Square  8.633333
# 2       Rogers Park  8.450000
# 3          Avondale  8.430000
# 4           Dunning  8.400000
# 5    North Lawndale  8.400000
# 6          New City  8.300000
# 7    Belmont Cragin  8.200000
# 8           Beverly  8.200000
# 9       Irving Park  8.100000
# 10           O'Hare  8.100000
# 11      Edison Park  8.000000
# 12     Norwood Park  8.000000
# 13          Pullman  8.000000
# 14        Edgewater  7.940909
# 15  Grand Boulevard  7.925000
# 16           Uptown  7.917391
# 17          Chatham  7.900000
# 18     Lincoln Park  7.858824
# 19    Armour Square  7.750000
# 20  Calumet Heights  7.700000
# 21        West Town  7.675000
# 22     North Center  7.600000
# 23      South Shore  7.600000
# 24   Lincoln Square  7.466667
# 25      Fuller Park  7.400000
# 26      Avalon Park  7.233333
# 27  Lower West Side  7.220000
# 28     Portage Park  7.150000
# 29             Loop  7.074194
# ...

# %% [markdown]
# Looking at the top five neighborhoods, lets see what sort of variability we are getting with the ratings for cafes.

# %%
sns.boxplot(x="title", y="rating", data=final_venue_df[final_venue_df['title'].isin(neighborhood_rating_df.iloc[:5]['title'].values)])
# Out:
# <AxesSubplot:xlabel='title', ylabel='rating'>

# %% [markdown]
# How about for the bottom five

# %%
sns.boxplot(x="title", y="rating", data=final_venue_df[final_venue_df['title'].isin(neighborhood_rating_df.iloc[-5:]['title'].values)])
# Out:
# <AxesSubplot:xlabel='title', ylabel='rating'>

# %% [markdown]
# Ratings distributions show a gaussian bell curve bar the 7.5ish rating where the count is down significantly

# %%
neighborhood_rating_df['rating'].plot(kind='hist')
plt.title("rating distribution")
plt.ylabel("number of neighborhoods")
plt.xlabel("rating")
# Out:
# Text(0.5, 0, 'rating')

# %% [markdown]
# One thing I am really curious about is the distribution of ratings among the neighborhoods. What I found is that the distribution was not equal at all. Some neighborhoods had ten or more venues that were rated, a handful had more than two, but fourteen of our neighborhoods had only one venue that was rated.
#
# If we are not careful, this can seriously bias any further analysis that we may attempt to do. This also suggests that building a model that takes into account some of the characteristics of each neighborhood may allow us to generalize to the neighborhoods with few rated venues better than we could just by simple data analysis

# %%
final_venue_df['title'].value_counts()
# Out:
# Loop               31
# Uptown             23
# Edgewater          22
# Lincoln Park       17
# West Town          16
# Hyde Park          14
# North Center       11
# Avondale           10
# Logan Square        9
# Albany Park         6
# Lower West Side     5
# Grand Boulevard     4
# Lake View           3
# Avalon Park         3
# Lincoln Square      3
# Beverly             2
# Rogers Park         2
# West Ridge          2
# Fuller Park         2
# Armour Square       2
# Calumet Heights     2
# Portage Park        2
# Belmont Cragin      1
# Chatham             1
# South Shore         1
# South Lawndale      1
# New City            1
# Norwood Park        1
# O'Hare              1
# Dunning             1
# Pullman             1
# Morgan Park         1
# Garfield Ridge      1
# North Lawndale      1
# Edison Park         1
# Irving Park         1
# Name: title, dtype: int64

# %% [markdown]
# Lets confirm that there isnt a relationship between the number of venues with ratings in a neighborhood and how positive the rating is. As we can see, the correlation is extremely weak.

# %%
final_venue_counts_df = final_venue_df['title'].value_counts().to_frame().reset_index()
final_venue_counts_df.rename(columns={'title':'count','index': 'title'}, inplace=True)
final_venue_counts_df = pd.merge(final_venue_counts_df, neighborhood_rating_df, on=['title'])
final_venue_counts_df.corr()
# Out:
#            count    rating
# count   1.000000 -0.109242
# rating -0.109242  1.000000

# %% [markdown]
# Before trying to build out a model, lets just get some specific numbers of our correlations between data.
#
# None of the pearson correlation values appear to be strong.
# None of the p-values here appear to be statistically significant.

# %%
from scipy import stats

pearson_coef, p_value = stats.pearsonr(final_venue_df['area_sq_mi'], final_venue_df["rating"])
print("For area_sq_mi and rating, The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)

pearson_coef, p_value = stats.pearsonr(final_venue_df['total'], final_venue_df["rating"])
print("For total and rating, The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)

pearson_coef, p_value = stats.pearsonr(final_venue_df['hispanic'], final_venue_df["rating"])
print("For hispanic and rating, The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P = ", p_value)
# Out:
# For area_sq_mi and rating, The Pearson Correlation Coefficient is 0.1259320028323061  with a P-value of P =  0.07198449455542519
# For total and rating, The Pearson Correlation Coefficient is 0.12197778258784311  with a P-value of P =  0.08145794960586908
# For hispanic and rating, The Pearson Correlation Coefficient is 0.18795510413347385  with a P-value of P =  0.006960104997051089

# %% [markdown]
# Lets plot all the cafe's in our dataset onto a map color coded for ratings. The darker the circle, the higher the rating. Perhaps this might give us insight into if a specific location in the city tends to produce higher locations. For example, maybe cafe's further north tend to get better ratings due to different mico-climates.
#
# The mapping below doesnt really show much correlation

# %%
map_clusters = folium.Map(location=[42.019306, -87.672078], zoom_start=11)
for lat, lon, rating in zip(final_venue_df['Venue Latitude'], final_venue_df['Venue Longitude'], final_venue_df['rating']):
    folium.CircleMarker(
        [lat, lon],
        radius=10,
        popup='test',
        color=colors.rgb2hex([0.0,0.0,0.0]),
        fill=True,
        fill_color=colors.rgb2hex([rating / 10,rating / 10,rating / 10]),
        fill_opacity=1.0
    ).add_to(map_clusters)
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %% [markdown]
# ### Modeling
#
# We next will try to build out a couple of models that can take in some of the features of each neighborhood and predict the rating for the cafe. Because we have such an uneven distribution of ratings among the neighborhoods, the average rating per neighborhood is not a good indicator of how a new cafe would be rated. Instead, modeling might find interesting combinations of features found in neighborhoods that will better help us understand which neighborhoods a cafe we recieve higher ratings for based on their own feature characterstics.
#
# Because I am looking for a output from the model that is not a classification, but a continous number, I will look to build some sort of linear model to start.

# %%
train_x = final_venue_df.iloc[:,-8:].values.tolist()
train_y = final_venue_df['rating'].values.tolist()

# %%
from sklearn import preprocessing
X = preprocessing.StandardScaler().fit(train_x).transform(train_x)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split( X, train_y, test_size=0.2, random_state=4)

# %% [markdown]
# Going to build a linear regression model.
#
# The results were very poor, with a r score of 0.09

# %%
# Building a linear model to see if we can predict ratings for a venue
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)
reg.score(X_train, y_train)
# Out:
# 0.095141962725933

# %% [markdown]
# Next going to try and see if a polynomial linear learner might work better.
#
# The results were better, but still very poor for the r-score

# %%
from sklearn.preprocessing import PolynomialFeatures

pr=PolynomialFeatures(degree=1)
x_pf=pr.fit_transform(train_x).astype(float)
x_pf.shape
# Out:
# (205, 9)

# %%
reg2 = LinearRegression().fit(x_pf, train_y)
reg2.score(x_pf, train_y)
# Out:
# 0.09389500927248928

# %% [markdown]
# Finally, let plot predicted outcomes verse actual outcomes of our model for the test dataset to get a visual idea of where we are going wrong.

# %%
predictions = []
outcomes = y_test

x_pf_test = pr.fit_transform(X_test).astype(float)
predictions = reg2.predict(x_pf_test)

# %%
plt.figure(figsize=(10,8))
plt.hist(outcomes, bins=5, alpha=0.5, label="predicted")
plt.hist(predictions, bins=5, alpha=0.5, label="actual")


plt.xlabel("Rating", size=14)
plt.ylabel("Count", size=14)
plt.title("Model Evaluation")
plt.legend(loc='upper right')

# %% [markdown]
# #### Conclusion
#
# The poor results for these models help bolster that nothing within the available data we have will help us build out a robust model that can help us predict how well a cafe is rated based on its neighborhood in Chicago. It could perhaps be that we are missing important information such as socio-economic status of a neighborhood or primary working industries for residents. Most likely though, ratings are probably more guided by how good of cafe you make or how cool your cafe is.
#
# I suspect that expanding this analysis to a larger region of the country may result in a more fruitful analysis, as although the neighborhoods of Chicago can be culturally diverse, they still will be much more similar that that of regions further away from each other in the country. Different cultures will likely value and rate cafe houses different.
#
# The results of this project were not a waste, as in science it is often just as important to show where correlation and causation are not as it is to show where they are. This study helped inform us that neighborhood differences such as size and ethinicity distributions will not impact ratings on Foursquare which was our indicator of success for a cafe. This frees entrepreneurs to pick any neighborhood within the city that they like best without fear that it was sub-optimal.
